# %% [markdown]
# <a href="https://colab.research.google.com/github/dave-heslop74/EMSC2010-W2-P1/blob/main/EMSC2010_W2_P1_NB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W2-P1-NB1

# %%
1+2
# Out:
# 3
